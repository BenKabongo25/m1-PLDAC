# %% [markdown]
# # Alfred : Etude du dataset

# %%
# !pip install gitpython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 4.1 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 4.8 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, gitdb, gitpython
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0

# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import git

# %%
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Chargement de données

# %%
# clonage du repository Alfred
git.Repo.clone_from("https://github.com/askforalfred/alfred.git", "alfred")
# Out:
# <git.repo.base.Repo '/content/alfred/.git'>

# %%
# chargement des données
#!wget https://ai2-vision-alfred.s3-us-west-2.amazonaws.com/json_feat_2.1.0.7z

# %%
# chemin du dossier du petit dataset
BASE_DIR = 'alfred/data/json_2.1.0/'
# nombre d'éléments 
print(len(os.listdir(BASE_DIR)))
# Out:
# 5

# %%
# récupère les données en filtrant les infos pertinentes
def get_info_from_file(file):
    # toutes les informations
    dic = json.load(file)

    # filtrage des informtions à conserver
    info = {}

    # identifiant de la tâche
    info['id'] = dic['task_id']

    # type de la tâche
    if 'task_type' in dic:
        info['type'] = dic['task_type']
    else:
        # pour les données de test
        info['type'] = 'UNKNOWN'
    
    # informations sur la scène
    scene = {}
    # récupération de la liste des objets
    objects = []
    for obj in dic['scene']['object_poses']:
        scene_object = {}
        name, id = obj['objectName'].split('_')
        # nom de l'objet
        scene_object['name'] = name
        # identifiant de l'objet
        scene_object['id'] = id
        # position de l'objet
        scene_object['position'] = [obj['position']['x'], obj['position']['y'], obj['position']['z']]
        # rotation de l'objet
        scene_object['rotation'] = [obj['rotation']['x'], obj['rotation']['y'], obj['rotation']['z']]
        objects.append(scene_object)
    scene['objects'] = objects
    info['scene'] = scene

    # récupération des annotations des experts
    descriptions = []
    for ann in dic['turk_annotations']['anns']:
        desc = {}
        # description
        desc['input'] = ann['task_desc']
        # découpage élémentaire
        desc['output'] = ann['high_descs']
        # votes : pas présent pour les données de test
        if 'votes' in ann:
            desc['score'] = round( np.mean(ann['votes']), 2 )
        else:
            desc['score'] = 0
        descriptions.append(desc)
    info['descriptions'] = descriptions

    return info

# %%
# base_dir : ex : alfred/data/json_2.1.0/train/
def get_data_from_dir(base_dir):
    data = []
    
    for dir1 in os.listdir(base_dir):
        if dir1 == '.DS_Store': continue
        
        subdir = base_dir + dir1 + '/'
        for dir2 in os.listdir(subdir):
            if dir2 == '.DS_Store': continue
            
            filename = subdir + dir2 + '/' + 'traj_data.json'
            with open(filename) as file:
                info = get_info_from_file(file)
                # ajout aux données
                data.append(info)

    return data

# %%
# base_dir : ex : alfred/data/json_2.1.0/tests_seen/
def get_data_from_test_dir(base_dir):
    data = []
    
    for dir1 in os.listdir(base_dir):
        if dir1 == '.DS_Store': continue
        
        filename = base_dir + dir1 + '/'  + 'traj_data.json'
        with open(filename) as file:
            info = get_info_from_file(file)
            # ajout aux données
            data.append(info)

    return data

# %%
base_train = BASE_DIR + 'train/'
base_valid_seen = BASE_DIR + 'valid_seen/'
base_valid_unseen = BASE_DIR + 'valid_unseen/'
base_test_seen = BASE_DIR + 'tests_seen/'
base_test_unseen = BASE_DIR + 'tests_unseen/'

print('Taille des dossiers')
print('Train :\t\t', len(os.listdir(base_train)))
print('Valid seen :\t', len(os.listdir(base_valid_seen)))
print('Valid unseen :\t', len(os.listdir(base_valid_unseen)))
print('Tests seen :\t', len(os.listdir(base_test_seen)))
print('Tests unseen :\t', len(os.listdir(base_test_unseen)))
# Out:
# Taille des dossiers
# Train :		 2435
# Valid seen :	 242
# Valid unseen :	 85
# Tests seen :	 483
# Tests unseen :	 488

# %%
data_train = get_data_from_dir(base_train)
print(len(data_train))
# Out:
# 6574

# %%
data_train[0]
# Out:
# {'id': 'trial_T20190908_073132_917743',
#  'type': 'pick_cool_then_place_in_recep',
#  'scene': {'objects': [{'name': 'SprayBottle',
#     'id': '4f8d0eee',
#     'position': [1.20097, 0.8857041, 2.477],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SprayBottle',
#     'id': '4f8d0eee',
#     'position': [-0.91988194, 0.749030352, 2.83014464],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': '4b57442b',
#     'position': [1.450345, 0.885864258, 2.58481264],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Glassbottle',
#     'id': '6018293c',
#     'position': [-0.0824483, 0.7592729, -0.533726156],
#     'rotation': [1.40334191e-14, 0.0, 0.0]},
#    {'name': 'Glassbottle',
#     'id': '6018293c',
#     'position': [0.951595068, 0.8870167, 2.15356255],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '1d6d1e51',
#     'position': [1.20097, 0.8874294, 2.692625],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Fork',
#     'id': '9f8771c2',
#     'position': [1.28637147, 0.9120486, 0.7067195],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spatula',
#     'id': '2f163330',
#     'position': [1.20740271, 0.9264999, -0.4283477],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spatula',
#     'id': '2f163330',
#     'position': [1.444309, 0.9264999, 0.7067195],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Egg',
#     'id': '1ede3fc6',
#     'position': [1.450345, 0.9204665, 2.692625],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': '1ede3fc6',
#     'position': [-0.130184531, 0.9462664, -0.933621049],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': '572193ee',
#     'position': [-1.29051554, 0.7481479, 2.83014464],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Plate',
#     'id': 'c933fa0b',
#     'position': [-1.383174, 0.750511765, 2.64457226],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Plate',
#     'id': 'c933fa0b',
#     'position': [-1.32594109, 1.6566093, 0.222244546],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': '268c1c72',
#     'position': [1.117845, 0.9082927, 2.36918736],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': '268c1c72',
#     'position': [1.28637147, 0.9334927, 0.1391859],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '57296338',
#     'position': [1.20097, 0.936028838, 2.15356255],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'e0c21b7c',
#     'position': [1.0880903, 0.117188632, 0.732311],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'e0c21b7c',
#     'position': [-1.01254034, 0.7502286, 2.459],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '7e041f70',
#     'position': [1.03472006, 0.884740651, 2.692625],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '7e041f70',
#     'position': [-1.16246915, 0.3400014, 0.778625369],
#     'rotation': [0.0, 89.99983, 0.0]},
#    {'name': 'Lettuce',
#     'id': '6438ff8b',
#     'position': [-1.20685482, 1.70792592, 0.8832667],
#     'rotation': [0.0, 89.99983, 0.0]},
#    {'name': 'Lettuce',
#     'id': '6438ff8b',
#     'position': [-1.43764663, 0.983068466, -0.477608353],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'b6eaf348',
#     'position': [1.20097, 0.8826062, 2.36918736],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'c297f602',
#     'position': [1.444309, 0.906500041, -0.4283477],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'c297f602',
#     'position': [1.21572745, 0.943699956, -0.633415341],
#     'rotation': [0.0, 320.3145, 0.0]},
#    {'name': 'Apple',
#     'id': '7daf87a0',
#     'position': [-0.91988194, 0.809103966, 2.273428],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bread',
#     'id': '74101882',
#     'position': [-1.01254034, 0.813041151, 1.90228331],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Glassbottle',
#     'id': '6018293c',
#     'position': [-1.01254034, 0.750342965, 2.64457226],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Fork',
#     'id': '9f8771c2',
#     'position': [1.444309, 0.9120486, 0.4229527],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Kettle',
#     'id': 'c40d8d1f',
#     'position': [1.128434, 0.91254133, 0.4229527],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '57296338',
#     'position': [1.444309, 0.961228848, 0.1391859],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Plate',
#     'id': 'c933fa0b',
#     'position': [-1.19785714, 0.750511765, 2.273428],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'CellPhone',
#     'id': 'e3d6b27e',
#     'position': [1.36722, 0.8840117, 2.15356255],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Lettuce',
#     'id': '6438ff8b',
#     'position': [1.238, 0.9697, -0.16],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pot',
#     'id': '92502562',
#     'position': [0.802, 0.9393, -0.7406],
#     'rotation': [0.0, 89.9998245, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'e0c21b7c',
#     'position': [-1.43365359, 0.9134286, -0.907535136],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'WineBottle',
#     'id': '6b7178a8',
#     'position': [-0.6586952, 0.9130287, -0.828023434],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spatula',
#     'id': '2f163330',
#     'position': [1.444309, 0.9264999, -0.144580841],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '7e041f70',
#     'position': [-1.26391578, 1.41969812, 1.197375],
#     'rotation': [0.0, 89.99983, 0.0]},
#    {'name': 'Apple',
#     'id': '7daf87a0',
#     'position': [0.951595068, 0.946504, 2.477],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': '572193ee',
#     'position': [-0.0824483, 0.7578041, -0.691273868],
#     'rotation': [1.40334191e-14, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': '268c1c72',
#     'position': [1.284095, 0.9082927, 2.80043745],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': '1ede3fc6',
#     'position': [0.0417298935, 0.792722642, -0.5731131],
#     'rotation': [1.40334191e-14, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '8429d040',
#     'position': [-0.503703535, 0.9084062, -0.430464923],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'b6eaf348',
#     'position': [0.250428259, 0.112944961, -0.5338761],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Potato',
#     'id': 'edec52fd',
#     'position': [1.30178607, 0.131182581, 1.44079888],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '432df619',
#     'position': [-1.01254034, 0.74966836, 2.273428],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': '4b57442b',
#     'position': [-1.09906554, 0.7755628, 0.209842056],
#     'rotation': [0.0, 179.999664, 0.0]},
#    {'name': 'Pan',
#     'id': 'a0065d6c',
#     'position': [0.5029, 0.9393, -0.4699],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '1d6d1e51',
#     'position': [-0.20662649, 0.7596856, -0.65188694],
#     'rotation': [0.0, 90.0, 1.40334191e-14]},
#    {'name': 'SprayBottle',
#     'id': '4f8d0eee',
#     'position': [-1.29051554, 0.749030352, 3.015717],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'c297f602',
#     'position': [-1.20685577, 1.2833575, 1.19737518],
#     'rotation': [0.0, 89.99983, 0.0]}]},
#  'descriptions': [{'input': 'Put chilled tomato in the microwave',
#    'output': ['Move forward towards the stove then turn left on the counter',
#     'Pick up the tomato from the counter',
#     'Turn to your left head to the fridge ',
#     'Open the fridge chill the tomato in take it out then close the fridge',
#     'Turn left move few steps then turn right to the microwave',
#     'Open the microwave put in the tomato'],
#    'score': 1.0},
#   {'input': 'Place a chilled tomato inside the microwave.',
#    'output': ['Walk to the stove and then turn left and look at the tomato on the counter.',
#     'Pick up the tomato on the counter.',
#     'Turn around and walk to the fridge.',
#     'Chill the tomato in the fridge and then pick the tomato back up and close the fridge.',
#     'Turn left and walk to the microwave to the left of the fridge.',
#     'Place the tomato inside the microwave and shut the microwave.'],
#    'score': 1.0},
#   {'input': 'Put a chilled tomato in a microwave.',
#    'output': ['move to the counter across from the fridge',
#     'pick up a tomato from the counter',
#     'move to the fridge behind you',
#     'chill the tomato in the fridge for a moment',
#     'move to the microwave to the left of you',
#     'put the tomato in the microwave'],
#    'score': 0.67}]}

# %%
data_valid_seen = get_data_from_dir(base_valid_seen)
print(len(data_valid_seen))
# Out:
# 251

# %%
data_valid_seen[0]
# Out:
# {'id': 'trial_T20190909_113054_894334',
#  'type': 'pick_and_place_simple',
#  'scene': {'objects': [{'name': 'CellPhone',
#     'id': 'e9073545',
#     'position': [0.5847936, 0.6474927, 0.5983121],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'Pen',
#     'id': '290c3680',
#     'position': [-0.934662342, 1.35304332, -2.22205615],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pencil',
#     'id': 'b9e0bc7f',
#     'position': [0.101288974, 0.148758918, -2.15765119],
#     'rotation': [0.0, 89.99995, 0.0]},
#    {'name': 'Pencil',
#     'id': 'b9e0bc7f',
#     'position': [1.6398344, 0.377508134, -0.9309873],
#     'rotation': [0.0, 179.999954, 0.0]},
#    {'name': 'CreditCard',
#     'id': '610c6ee4',
#     'position': [1.61593139, 0.3743477, -1.10202527],
#     'rotation': [0.0, 89.99995, 0.0]},
#    {'name': 'CreditCard',
#     'id': '610c6ee4',
#     'position': [1.80726135, 0.680996, -1.06536758],
#     'rotation': [0.0, 269.999939, 0.0]},
#    {'name': 'Book',
#     'id': '0c07f8c5',
#     'position': [0.5847938, 0.6466787, -0.1203123],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'Book',
#     'id': '0c07f8c5',
#     'position': [-1.39628816, 1.77842414, -2.22181821],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'AlarmClock',
#     'id': '9f2759ac',
#     'position': [1.58172226, 0.680965543, -1.06536782],
#     'rotation': [0.0, 269.999939, 0.0]},
#    {'name': 'AlarmClock',
#     'id': '9f2759ac',
#     'position': [-0.705143, 1.77736557, -2.04186821],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Laptop',
#     'id': 'f5306a34',
#     'position': [-0.9355247, 0.835999966, -1.753535],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Book',
#     'id': '0c07f8c5',
#     'position': [1.15282929, 0.6466787, 0.239000022],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'Box',
#     'id': '7d6f7754',
#     'position': [-0.424, 2.065, -2.027],
#     'rotation': [0.0, 352.503357, 0.0]},
#    {'name': 'Pillow',
#     'id': 'f371ef62',
#     'position': [0.8688115, 0.739931166, 0.418656021],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'AlarmClock',
#     'id': '9f2759ac',
#     'position': [-1.62666988, 0.837965548, -2.18582034],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'BasketBall',
#     'id': 'd0749346',
#     'position': [-0.3372621, 0.120000444, 1.0316453],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'BaseballBat',
#     'id': '124fb40c',
#     'position': [-1.602, 0.022, 0.356],
#     'rotation': [90.0, 8.736932, 0.0]},
#    {'name': 'Pen',
#     'id': '290c3680',
#     'position': [-1.16590643, 0.843652844, -2.077749],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'CellPhone',
#     'id': 'e9073545',
#     'position': [2.00488257, 0.6474927, 0.418656439],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'TennisRacket',
#     'id': 'de7db8d2',
#     'position': [-1.667, 0.0, 0.818],
#     'rotation': [90.0, 29.999939, 0.0]},
#    {'name': 'Laptop',
#     'id': 'f5306a34',
#     'position': [1.152829, 0.6436545, 0.7779683],
#     'rotation': [0.0, -2.3905659e-05, 0.0]},
#    {'name': 'Pencil',
#     'id': 'b9e0bc7f',
#     'position': [-0.9018051, 1.35068166, -2.074822],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'KeyChain',
#     'id': '90079c68',
#     'position': [-1.62666988, 1.77754712, -1.98188484],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'CreditCard',
#     'id': '610c6ee4',
#     'position': [-0.9355247, 0.837996, -1.96967769],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'CD',
#     'id': '1962be34',
#     'position': [-1.16590643, 1.77700675, -2.16183472],
#     'rotation': [0.0, 0.0, 0.0]}]},
#  'descriptions': [{'input': 'Place a pencil on a desk.',
#    'output': ['Turn left and walk to the left side of the desk, with the trash bin on the floor.',
#     'Pick up the pencil from the trash bin.',
#     'Look up at the desk.',
#     'Place the pencil on the desk.'],
#    'score': 1.0},
#   {'input': 'Take a pencil out of the trash and put it on the desk',
#    'output': ['Turn around and then face to your right twice so that you are facing the side of the trash can',
#     'Pick up a pencil out of the trash can',
#     'Look up from the trash can',
#     'Put the pencil down on the desk'],
#    'score': 1.0},
#   {'input': 'Move a pencil from a small black bin to a wooden desk.',
#    'output': ['Walk over to the small black bin next to the wooden desk on your left.',
#     'Pick up the pencil out of the small black bin.',
#     'Look up at the wooden desk in front of you.',
#     'Put the pencil on the wooden desk.'],
#    'score': 1.0}]}

# %%
data_valid_unseen = get_data_from_dir(base_valid_unseen)
print(len(data_valid_unseen))
# Out:
# 255

# %%
data_valid_unseen[0]
# Out:
# {'id': 'trial_T20190907_194015_037530',
#  'type': 'pick_and_place_with_movable_recep',
#  'scene': {'objects': [{'name': 'CreditCard',
#     'id': '0304788b',
#     'position': [-1.10427678, 0.930496, -0.643],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': 'f11e4d33',
#     'position': [1.21275449, 2.20769572, -1.40890622],
#     'rotation': [-7.062251e-30, 270.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': 'b86b8dfc',
#     'position': [-0.6247657, 0.933542, 0.16271013],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': 'b86b8dfc',
#     'position': [-1.167114, 0.9335421, 0.144211411],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': 'b86b8dfc',
#     'position': [-0.698599339, 0.933542, -1.2314738],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Fork',
#     'id': '1427a484',
#     'position': [-0.772433162, 0.9340485, 0.16271013],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Fork',
#     'id': '1427a484',
#     'position': [0.874041557, 0.154419124, -0.729917049],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '4fda088e',
#     'position': [-0.698599339, 0.9346293, -1.3088007],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': '12782efe',
#     'position': [0.844407558, 1.39900482, 1.34940743],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Cup',
#     'id': '12782efe',
#     'position': [1.02947235, 0.908499539, -1.79397738],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '49f13c52',
#     'position': [0.688659847, 0.9076062, -1.87965155],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'ae82d920',
#     'position': [0.94426924, 0.9076062, -0.381795347],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bread',
#     'id': 'c3a328b9',
#     'position': [1.02679622, 0.9441694, 1.063186],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Mug',
#     'id': '63934229',
#     'position': [1.02947235, 0.9063, -0.5555908],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Apple',
#     'id': '560cdd24',
#     'position': [1.0875926, 1.45207322, 1.06318486],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Apple',
#     'id': '560cdd24',
#     'position': [-0.960000038, 0.229277521, 0.6086027],
#     'rotation': [0.0, 180.000061, 0.0]},
#    {'name': 'Statue',
#     'id': 'e620c55b',
#     'position': [-1.167114, 0.9363878, -0.118192375],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Glassbottle',
#     'id': 'dc08ca77',
#     'position': [-1.10427678, 0.9342167, -0.380596161],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bread',
#     'id': 'c3a328b9',
#     'position': [0.9052038, 0.9441694, 1.44481385],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'CreditCard',
#     'id': '0304788b',
#     'position': [0.8740415, 0.150866568, -0.5714829],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'CellPhone',
#     'id': 'ef488591',
#     'position': [-0.5509312, 0.930409431, -1.54078138],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Potato',
#     'id': 'ccc73403',
#     'position': [-0.8655939, 0.209494978, 0.608602643],
#     'rotation': [0.0, 270.000061, 0.0]},
#    {'name': 'Knife',
#     'id': 'f88e84d1',
#     'position': [0.8590662, 0.9348277, -0.207999855],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Fork',
#     'id': '1427a484',
#     'position': [0.7938088, 0.154419124, -0.6507],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Pan',
#     'id': 'fee30bc3',
#     'position': [0.8484889, 0.9462139, -1.08015645],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Lettuce',
#     'id': '5e722375',
#     'position': [0.8668195, 1.688561, 1.20919585],
#     'rotation': [9.74635, 11.11654, 359.152344]},
#    {'name': 'Plate',
#     'id': 'f4832794',
#     'position': [-1.77661455, 0.88516295, 2.7196],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Apple',
#     'id': '560cdd24',
#     'position': [0.688659847, 0.961567938, -0.729386151],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pot',
#     'id': '54bd4d72',
#     'position': [1.0776, 0.950000048, -1.5042],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spatula',
#     'id': 'ef7cb958',
#     'position': [-0.6427196, 0.7957322, -0.918476],
#     'rotation': [1.40334208e-14, -4.82967334e-05, -1.18128613e-20]},
#    {'name': 'PaperTowelRoll',
#     'id': '412e7506',
#     'position': [-1.41846323, 1.03778529, -1.16780758],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '451cbeb9',
#     'position': [0.965999961, 1.175689, 1.44481516],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Egg',
#     'id': 'fe6a8905',
#     'position': [0.94426924, 0.9491859, -0.5555908],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '49f13c52',
#     'position': [-0.6247653, 0.9298061, -1.3088007],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'ae82d920',
#     'position': [1.19987857, 0.9076062, -1.96532583],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Vase',
#     'id': '0c323360',
#     'position': [-1.423, 0.169, 2.621],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': 'b86b8dfc',
#     'position': [1.11467552, 0.9113421, -0.381795347],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': '8542e5a1',
#     'position': [1.02947235, 0.911669135, -0.03420466],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Vase',
#     'id': 'aa254d2e',
#     'position': [1.19410288, 1.66736877, -0.40134418],
#     'rotation': [-7.062251e-30, 270.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '6f54d42d',
#     'position': [1.02679634, 1.6463263, 1.15859246],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': 'f11e4d33',
#     'position': [-0.9201006, 0.933064163, 0.23935467],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '4fda088e',
#     'position': [0.794475436, 0.495444745, -0.6900609],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Cup',
#     'id': '12782efe',
#     'position': [0.7836114, 1.640205, 0.9677772],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Mug',
#     'id': '63934229',
#     'position': [1.03971815, 2.20313168, -1.51781249],
#     'rotation': [-7.062251e-30, 270.0, 0.0]}]},
#  'descriptions': [{'input': 'Put a pan with a knife in it in the sink.',
#    'output': ['Turn around, go to the end of the kitchen island, then turn left.',
#     'Pick up the butter knife on the kitchen island, in front of the fork.',
#     'Turn left, go straight, then turn left to face the stove.',
#     'Put the butter knife in the pan on the stove.',
#     'Pick up the pan on the stove, with the butter knife in it.',
#     'Turn left, move forward, then turn left to face the sink.',
#     'Put the pan in the sink.'],
#    'score': 1.0},
#   {'input': 'put the knife to the pan on the stove, move the pan into the sink',
#    'output': ['turn around, walk to the counter at the end on the left',
#     'grab the knife from the counter',
#     'turn around to the stove',
#     'put the knife in the pan on the stove',
#     'grab the pan with the knife',
#     'turn around to the sink',
#     'put the pan in the sink'],
#    'score': 1.0},
#   {'input': 'Put the pan and knife in the sink.',
#    'output': ['Turn around and go to the end of the island.',
#     'Pick up the knife from the counter.',
#     'Turn around and take the knife to the stove.',
#     'Put the knife in the pan on the front left of the stove.',
#     'Pick up the pan and knife from the stove.',
#     'Turn around to the sink.',
#     'Put the pan and knife in the sink.'],
#    'score': 1.0}]}

# %%
data_test_seen = get_data_from_test_dir(base_test_seen)
print(len(data_test_seen))
# Out:
# 483

# %%
data_test_seen[0]
# Out:
# {'id': 'trial_T20190908_064522_624362',
#  'type': 'UNKNOWN',
#  'scene': {'objects': [{'name': 'Potato',
#     'id': '027e0a30',
#     'position': [-2.05486441, 0.832557559, -3.70596051],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Potato',
#     'id': '027e0a30',
#     'position': [-0.8554549, 0.9336739, 0.8439424],
#     'rotation': [0.0, 270.000336, 0.0]},
#    {'name': 'DishSponge',
#     'id': '11e4138d',
#     'position': [0.62322855, 0.760119259, -0.061030075],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': '11e4138d',
#     'position': [0.5821031, 0.8831642, -0.10800001],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '0ad5c562',
#     'position': [-1.05636227, 0.900662839, 0.8439436],
#     'rotation': [0.0, 270.000336, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '0ad5c562',
#     'position': [-2.13780355, 0.70183146, -1.09179544],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '93a81026',
#     'position': [0.9619548, 0.6665257, 0.387266],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '93a81026',
#     'position': [0.721681535, 0.6657294, 0.387266],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Fork',
#     'id': '34f12e87',
#     'position': [0.7204354, 0.7611036, -0.188901335],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': 'cb0de209',
#     'position': [0.7323308, 0.0143482685, -0.119339228],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': '33d4fba0',
#     'position': [-1.71959925, 0.7248699, -1.30794287],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Knife',
#     'id': '33d4fba0',
#     'position': [-1.0563612, 0.9237013, 1.01548123],
#     'rotation': [0.0, 90.00033, 0.0]},
#    {'name': 'Tomato',
#     'id': '5a2cfc73',
#     'position': [0.877196848, 0.9319887, -0.314791471],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '5a2cfc73',
#     'position': [0.746874, 0.5143165, -2.11325],
#     'rotation': [0.0, 270.000183, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'd7803c74',
#     'position': [0.6616132, 0.6646764, 0.508934],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'd7803c74',
#     'position': [0.842995167, 0.0149986744, 0.011385709],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '737b77b7',
#     'position': [0.9038171, 1.46226478, 0.349752665],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '886fcaf3',
#     'position': [0.6216665, 0.0120247006, 0.07674818],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '886fcaf3',
#     'position': [0.721681535, 0.661702454, 0.6306019],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bread',
#     'id': '42314d78',
#     'position': [0.841818154, 0.708858848, 0.508934],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': '288ff1e3',
#     'position': [0.746874452, 1.36962759, -1.95800006],
#     'rotation': [0.0, 270.000183, 0.0]},
#    {'name': 'Pot',
#     'id': 'cde1951c',
#     'position': [-1.552, 0.9306, 0.785],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Plate',
#     'id': '2b33f66e',
#     'position': [-2.02399945, 0.69248, -1.44700074],
#     'rotation': [-1.62284123e-05, -0.000303944078, -1.66631326e-05]},
#    {'name': 'Fork',
#     'id': '34f12e87',
#     'position': [-1.97052181, 0.7023379, -0.983721733],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': 'd7803c74',
#     'position': [0.6616132, 0.6638801, 0.326432049],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Apple',
#     'id': '093f2b24',
#     'position': [1.04067874, 0.9370899, -0.460193217],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pan',
#     'id': '63693e0a',
#     'position': [-2.097, 0.9306, 0.785],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': 'c79ff911',
#     'position': [0.8837527, 0.8091614, -0.735619843],
#     'rotation': [7.58303337e-22, 270.0, -1.40334191e-14]},
#    {'name': 'Spatula',
#     'id': '8142ce7b',
#     'position': [0.6729982, 0.787556052, -0.845712662],
#     'rotation': [-1.40334191e-14, 180.0, 0.0]},
#    {'name': 'Potato',
#     'id': '027e0a30',
#     'position': [-1.26099992, 0.08530182, -3.68420362],
#     'rotation': [0.0, 269.999878, 0.0]},
#    {'name': 'Cup',
#     'id': 'cb0de209',
#     'position': [0.7151491, 0.7711859, -0.7356198],
#     'rotation': [7.58303337e-22, 270.0, -1.40334191e-14]},
#    {'name': 'SaltShaker',
#     'id': '886fcaf3',
#     'position': [0.877196848, 0.8799061, -0.10800001],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': '87875872',
#     'position': [-1.63595831, 0.69809556, -1.19986916],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '0ad5c562',
#     'position': [0.754, 0.7553387, -0.743],
#     'rotation': [0.0, 44.9999161, 0.0]},
#    {'name': 'DishSponge',
#     'id': '11e4138d',
#     'position': [-1.26100016, 0.05181289, -3.57439852],
#     'rotation': [0.0, 269.999878, 0.0]},
#    {'name': 'Bread',
#     'id': '42314d78',
#     'position': [-0.0518239737, 0.9440833, 1.10124457],
#     'rotation': [0.0, 270.000336, 0.0]},
#    {'name': 'Lettuce',
#     'id': '0ad3089c',
#     'position': [0.785668552, 0.7519335, -1.88037515],
#     'rotation': [0.0, 270.000183, 0.0]},
#    {'name': 'Tomato',
#     'id': '5a2cfc73',
#     'position': [0.6692867, 0.5143165, -1.95799983],
#     'rotation': [0.0, 270.000183, 0.0]},
#    {'name': 'Spoon',
#     'id': '93a81026',
#     'position': [0.7690388, 0.7609973, 0.00290554762],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': '33d4fba0',
#     'position': [0.1490823, 0.923701346, 0.9297056],
#     'rotation': [0.0, 270.000336, 0.0]},
#    {'name': 'Mug',
#     'id': '288ff1e3',
#     'position': [0.708079934, 1.15372765, -2.190875],
#     'rotation': [0.0, 270.000183, 0.0]},
#    {'name': 'Bowl',
#     'id': '737b77b7',
#     'position': [0.8582397, 1.46226478, -0.146107078],
#     'rotation': [0.0, 0.0, 0.0]}]},
#  'descriptions': [{'input': 'Put a chilled slice of potato back in the microwave.',
#    'output': ['Turn around and go to the small white table on the other side.',
#     'Pick up the yellow knife behind the salt shaker from the table.',
#     'Turn left and go to the table with the microwave on top on the other side. ',
#     'Cut the potato inside the microwave.',
#     'Place the knife inside the microwave.',
#     'Take one slice of the potato. ',
#     'Turn around and go to the front of the refrigerator. ',
#     'Chill the potato slice next to the lettuce and take it out. ',
#     'Turn around to go back to the microwave.',
#     'Place the potato slice next to the knife and the potato.'],
#    'score': 0},
#   {'input': 'To chill a piece of potato and put it in the microwave. ',
#    'output': ['Turn around and walk to the white table with the wooden chair. ',
#     "Pick up the knife that's behind the salt shaker. ",
#     'Walk to the microwave on the left. ',
#     'Open the microwave door. ',
#     "Slice the potato that's in the microwave, put the knife down in the microwave. ",
#     'Take a piece of potato out of the microwave, close the microwave door. ',
#     'Turn around and walk to the fridge on the right. ',
#     'Put the piece of potato in the fridge to the right of the lettuce, close the door, take the piece of potato out of the fridge, close the door. ',
#     'Walk back over to the microwave. ',
#     'Put the piece of potato inside the microwave and shut the door. '],
#    'score': 0},
#   {'input': 'Preparing a slice of potato and putting it in the microwave',
#    'output': ['Turn around and go to the small table just to the right',
#     'Pick up the knife from behind the salt shaker',
#     'Move to the microwave to the left of the table',
#     'Open the microwave and cut the potato in the microwave',
#     'Put the knife in the microwave',
#     'Take a slice of potato and then close the microwave',
#     'Turn to the left and go to the fridge',
#     'Open the fridge and put the the slice in the fridge, close the fridge, wait, open the fridge and remove the potato slice, close the fridge',
#     'Turn around and move to the microwave to the left',
#     'Open the microwave, put the slice inside behind the knife and close the microwave'],
#    'score': 0}]}

# %%
data_test_unseen = get_data_from_test_dir(base_test_unseen)
print(len(data_test_unseen))
# Out:
# 488

# %%
data_test_unseen[0]
# Out:
# {'id': 'trial_T20190907_190822_091724',
#  'type': 'UNKNOWN',
#  'scene': {'objects': [{'name': 'Potato',
#     'id': '623293af',
#     'position': [-0.08721179, 0.8006406, -0.6519],
#     'rotation': [0.0, 90.0, 1.40334191e-14]},
#    {'name': 'Potato',
#     'id': '623293af',
#     'position': [2.77700067, 1.32367122, -0.644],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Kettle',
#     'id': '22c296f5',
#     'position': [1.68890381, 0.9128413, 1.299],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '1ff7ea32',
#     'position': [0.123259753, 0.7658982, -0.6519],
#     'rotation': [1.40334191e-14, 0.0, 0.0]},
#    {'name': 'Pot',
#     'id': '8f9d0722',
#     'position': [2.48830628, 0.9155004, 1.46853542],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pot',
#     'id': '8f9d0722',
#     'position': [0.2815, 0.9646, 1.0827],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '8e187b06',
#     'position': [1.276236, 0.7735443, -0.4601],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '8e187b06',
#     'position': [0.123259753, 0.766985536, -0.707179844],
#     'rotation': [1.40334191e-14, 0.0, 0.0]},
#    {'name': 'Fork',
#     'id': '8821c838',
#     'position': [-0.157368958, 0.7664047, -0.707179844],
#     'rotation': [0.0, 90.0, 1.40334191e-14]},
#    {'name': 'Plate',
#     'id': '833efe73',
#     'position': [0.3378849, 2.159573, 1.46709991],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': 'ade1bf23',
#     'position': [2.777, 0.7231746, -0.5659157],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Cup',
#     'id': 'ade1bf23',
#     'position': [1.14160466, 1.65341234, 1.42959452],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': 'fa9bfbf3',
#     'position': [2.15642977, 0.949392557, -0.854303062],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': 'fa9bfbf3',
#     'position': [1.42243636, 0.949392557, 1.55330312],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': 'd587bd39',
#     'position': [1.141888, 0.944237232, -0.430464655],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': 'd587bd39',
#     'position': [2.22183871, 0.944237232, 1.299],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': '6709809e',
#     'position': [1.59794772, 1.660043, 1.39413822],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '3002d0e0',
#     'position': [-0.05552353, 0.9429815, 1.38376772],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '42a3ea18',
#     'position': [-0.990395248, 0.8172332, -1.47309279],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '42a3ea18',
#     'position': [-0.0723736, 1.65075, -0.69653827],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'd5857586',
#     'position': [-0.9114925, 0.8172332, -1.41139507],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'd5857586',
#     'position': [0.825199962, 1.65192986, -0.849410653],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Bread',
#     'id': '438c212d',
#     'position': [-0.198914126, 0.9697301, 1.21423233],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'be26e544',
#     'position': [1.428362, 0.9681, -0.577148259],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'be26e544',
#     'position': [1.79785144, 0.109477758, -0.495924532],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Apple',
#     'id': 'f8702692',
#     'position': [2.77700067, 1.35750234, -0.775249958],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SoapBottle',
#     'id': '6709809e',
#     'position': [-0.210226372, 1.660043, -0.734719157],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Plate',
#     'id': '833efe73',
#     'position': [2.211671, 0.9027688, -0.462893546],
#     'rotation': [-0.000137127339, -0.000280028878, 2.32581642e-05]},
#    {'name': 'Fork',
#     'id': '8821c838',
#     'position': [-0.62153697, 0.821475565, -1.20633483],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Pot',
#     'id': '8f9d0722',
#     'position': [2.18873835, 0.118178129, 1.1565],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bread',
#     'id': '438c212d',
#     'position': [2.75477362, 0.9697301, 1.299],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Egg',
#     'id': 'fa9bfbf3',
#     'position': [2.59151363, 1.32647932, -0.51275],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Kettle',
#     'id': '22c296f5',
#     'position': [0.2815, 0.9646, 1.3473],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Tomato',
#     'id': '3002d0e0',
#     'position': [-0.7665147, 0.852108538, -1.2576],
#     'rotation': [0.0, 90.0, 0.0]},
#    {'name': 'Cup',
#     'id': 'ade1bf23',
#     'position': [1.94574785, 1.65223253, -0.7729],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'Spatula',
#     'id': '06605fb9',
#     'position': [2.48830628, 0.9267999, 1.21423233],
#     'rotation': [0.0, 270.0, 0.0]},
#    {'name': 'Apple',
#     'id': 'f8702692',
#     'position': [2.71517158, 1.6323024, -0.578375],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Pan',
#     'id': 'aedf19ac',
#     'position': [2.83882976, 1.01879621, -0.709625],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Lettuce',
#     'id': 'b1219d22',
#     'position': [1.42243636, 0.992467642, 1.21423233],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'SaltShaker',
#     'id': '42a3ea18',
#     'position': [0.812929034, 2.150197, 1.584379],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Knife',
#     'id': 'd587bd39',
#     'position': [1.95537138, 0.944237232, 1.044697],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Potato',
#     'id': '623293af',
#     'position': [1.95537138, 0.946584463, 1.299],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'PepperShaker',
#     'id': 'd5857586',
#     'position': [0.8882526, 0.9081062, -0.6],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'ButterKnife',
#     'id': '1ff7ea32',
#     'position': [1.42243636, 0.9118421, 1.044697],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Bowl',
#     'id': '22ae7932',
#     'position': [-0.836600065, 0.818763256, -1.11064851],
#     'rotation': [0.0, 180.0, 0.0]},
#    {'name': 'DishSponge',
#     'id': '58643e74',
#     'position': [-0.8878651, 0.820491254, -1.32811511],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Spoon',
#     'id': '8e187b06',
#     'position': [0.6346172, 0.9129294, -0.5152323],
#     'rotation': [0.0, 0.0, 0.0]},
#    {'name': 'Mug',
#     'id': 'be26e544',
#     'position': [0.4150349, 1.77948546, 1.42383158],
#     'rotation': [0.0, 179.999664, 0.0]}]},
#  'descriptions': [{'input': 'Put a heated tomato slice on the table.',
#    'output': ['Turn right and walk to the counter on the left with knives, a potato, and a kettle.',
#     'Pick up the knife from the front of the counter.',
#     'Turn left and carry the knife to a counter with a tomato and bread.',
#     'Slice the tomato to the right of the loaf of bread.',
#     'Turn right and walk to the table.',
#     'Set the knife down on the table with the handle up.',
#     'Turn left and walk to the counter with the tomato and the loaf of bread.',
#     'Pick up a slice of tomato.',
#     'Carry the tomato to the microwave to the right of the counter.',
#     'Put the slice of tomato in the microwave and turn it on.  Take the tomato slice out.',
#     'Turn left and walk toward the window, then turn left and walk to the table.',
#     'Put the tomato slice in front of the knife on the table.'],
#    'score': 0},
#   {'input': 'Cut and cook a tomato, put the tomato on the round table.',
#    'output': ['Turn right and walk past the stove then turn left to face the counter with the kettle.',
#     'Pick up the closest knife from the counter.',
#     'Turn left and walk to the counter on the left side of the stove with the loaf of bread.',
#     'Slice the tomato on the counter next to the bread.',
#     'Turn around and walk to the round table with a table cloth on it.',
#     'Stick the knife point side down into the top of table.',
#     'Turn around and walk to the counter to the left of the stove with the tomato on it.',
#     'Pick up a piece of tomato from the counter.',
#     'Turn and face the stove to your right.',
#     'Cook the piece of tomato in the microwave above the stove then remove the tomato from the microwave.',
#     'Turn left then left again and walk to the round table with the table cloth on it.',
#     'Put the tomato on the table near the knife.'],
#    'score': 0},
#   {'input': 'Put a piece of cooked pepper on the gray table.',
#    'output': ['Cross the kitchen and face the counter on the left.',
#     "Pick up the knife that's closest to the edge of the counter.",
#     'Bring the knife with you and go face counter on the left of the stove.',
#     'Slice the red pepper sitting to the right of the bread with the knife.',
#     'Bring the knife to the small gray table on the far side of the room.',
#     'Put the knife down on the gray table.',
#     'Go back over to where you sliced the pepper.',
#     'Pick up a piece of the pepper from the counter.',
#     'Bring the pepper with you and move to the right, then look up and face the microwave.',
#     'Put the pepper in the microwave and cook it, then take it out again.',
#     'Bring the cooked pepper over to the gray table where you put the knife.',
#     'Put the pepper down on the table in front of the knife.'],
#    'score': 0}]}

# %%
all_data = data_train + data_valid_seen + data_valid_unseen + data_test_seen + data_test_unseen
print(len(all_data))
# Out:
# 8051

# %%
# Nombre d'éléments dont on connait le type de tâche
KNOWN_TYPE_SIZE = len(data_train) + len(data_valid_seen) + len(data_valid_unseen)
print(KNOWN_TYPE_SIZE)
# Out:
# 7080

# %% [markdown]
# ## Types de tâches
#
# Observons quels sont les différentes types de tâches de notre dataset. Etudions notamment la fréquence de chacune.
#
# Après une étude générale du dataset, nous pourrons faire une étude par type d'instructions.

# %%
# compte les occurences des différentes taches existentes du dataset
def get_task_types(data):
    types = dict()

    for x in data:
        type_ = x['type'].strip()
        if type_ not in types:
            types[type_] = 0

        types[type_] += 1

    return types

# %%
task_types = get_task_types(all_data)
tmpdf = pd.DataFrame()
tmpdf['Type'] = task_types.keys()
tmpdf['Count'] = task_types.values()
tmpdf.sort_values(by='Count')
# Out:
#                                 Type  Count
# 4               look_at_obj_in_light    794
# 5     pick_clean_then_place_in_recep    968
# 7                            UNKNOWN    971
# 0      pick_cool_then_place_in_recep    994
# 1      pick_heat_then_place_in_recep    994
# 3  pick_and_place_with_movable_recep   1055
# 2              pick_and_place_simple   1110
# 6             pick_two_obj_and_place   1165

# %% [markdown]
# ## Classification des instructions par types
#
# Etant donné la description de haut niveau d'une instructions, peut-on prédire son type.

# %%
def get_input_and_type_from_data(data):
    input = []
    types = []

    for x in data:
        if x['type'] == 'UNKNOWN': continue
        for desc in x['descriptions']:
            input.append(desc['input'])
            types.append(x['type'])

    return input, types

# %%
input_types_df = pd.DataFrame()
input_types_df['input'], input_types_df['types'] = get_input_and_type_from_data(all_data)
input_types_df.head(10)
# Out:
#                                                input  \
# 0                Put chilled tomato in the microwave
# 1       Place a chilled tomato inside the microwave.
# 2               Put a chilled tomato in a microwave.
# 3  cool the tomato in the refrigerator, put the t...
# 4            Put a chilled tomato in the microwave.
# 5          place a cold tomato in the microwave oven
# 6                     Chill and microwave a tomato.
# 7            Cool a tomato and put it into microwave
# 8               Put a cold tomato in the microwave.
# 9  Put a heated cup on the counter left of the st...
#
#                            types
# 0  pick_cool_then_place_in_recep
# 1  pick_cool_then_place_in_recep
# 2  pick_cool_then_place_in_recep
# 3  pick_cool_then_place_in_recep
# 4  pick_cool_then_place_in_recep
# 5  pick_cool_then_place_in_recep
# 6  pick_cool_then_place_in_recep
# 7  pick_cool_then_place_in_recep
# 8  pick_cool_then_place_in_recep
# 9  pick_heat_then_place_in_recep

# %%
uniques = np.unique(input_types_df.types)
types_to_int = dict(zip(uniques, np.arange(len(uniques))))
types_to_int
# Out:
# {'look_at_obj_in_light': 0,
#  'pick_and_place_simple': 1,
#  'pick_and_place_with_movable_recep': 2,
#  'pick_clean_then_place_in_recep': 3,
#  'pick_cool_then_place_in_recep': 4,
#  'pick_heat_then_place_in_recep': 5,
#  'pick_two_obj_and_place': 6}

# %%
input_types_df['y'] = input_types_df['types'].map(types_to_int)
input_types_df.head(10)
# Out:
#                                                input  \
# 0                Put chilled tomato in the microwave
# 1       Place a chilled tomato inside the microwave.
# 2               Put a chilled tomato in a microwave.
# 3  cool the tomato in the refrigerator, put the t...
# 4            Put a chilled tomato in the microwave.
# 5          place a cold tomato in the microwave oven
# 6                     Chill and microwave a tomato.
# 7            Cool a tomato and put it into microwave
# 8               Put a cold tomato in the microwave.
# 9  Put a heated cup on the counter left of the st...
#
#                            types  y
# 0  pick_cool_then_place_in_recep  4
# 1  pick_cool_then_place_in_recep  4
# 2  pick_cool_then_place_in_recep  4
# 3  pick_cool_then_place_in_recep  4
# 4  pick_cool_then_place_in_recep  4
# 5  pick_cool_then_place_in_recep  4
# 6  pick_cool_then_place_in_recep  4
# 7  pick_cool_then_place_in_recep  4
# 8  pick_cool_then_place_in_recep  4
# 9  pick_heat_then_place_in_recep  5

# %%
# classification
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(input_types_df['input'], input_types_df['y'], 
                                                    test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

clf = LogisticRegression()
clf.fit(X_train_tfidf, y_train)

y_pred = clf.predict(X_test_tfidf)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       476
#            1       0.86      0.93      0.89       709
#            2       0.92      0.96      0.94       701
#            3       0.98      0.94      0.96       623
#            4       0.92      0.92      0.92       614
#            5       0.95      0.96      0.96       657
#            6       0.98      0.91      0.95       754
#
#     accuracy                           0.94      4534
#    macro avg       0.95      0.94      0.94      4534
# weighted avg       0.94      0.94      0.94      4534
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
for type, y in types_to_int.items():
    class_idx = list(input_types_df['y'].unique()).index(y)
    print(f"Performance {type} ({y}):")
    print(classification_report(y_test, y_pred, labels=[y]))
# Out:
# Performance look_at_obj_in_light (0):
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       476
#
#    micro avg       1.00      0.98      0.99       476
#    macro avg       1.00      0.98      0.99       476
# weighted avg       1.00      0.98      0.99       476
#
# Performance pick_and_place_simple (1):
#               precision    recall  f1-score   support
#
#            1       0.86      0.93      0.89       709
#
#    micro avg       0.86      0.93      0.89       709
#    macro avg       0.86      0.93      0.89       709
# weighted avg       0.86      0.93      0.89       709
#
# Performance pick_and_place_with_movable_recep (2):
#               precision    recall  f1-score   support
#
#            2       0.92      0.96      0.94       701
#
#    micro avg       0.92      0.96      0.94       701
#    macro avg       0.92      0.96      0.94       701
# weighted avg       0.92      0.96      0.94       701
#
# Performance pick_clean_then_place_in_recep (3):
#               precision    recall  f1-score   support
#
#            3       0.98      0.94      0.96       623
#
#    micro avg       0.98      0.94      0.96       623
#    macro avg       0.98      0.94      0.96       623
# weighted avg       0.98      0.94      0.96       623
#
# Performance pick_cool_then_place_in_recep (4):
#               precision    recall  f1-score   support
#
#            4       0.92      0.92      0.92       614
#
#    micro avg       0.92      0.92      0.92       614
#    macro avg       0.92      0.92      0.92       614
# weighted avg       0.92      0.92      0.92       614
#
# Performance pick_heat_then_place_in_recep (5):
#               precision    recall  f1-score   support
#
#            5       0.95      0.96      0.96       657
#
#    micro avg       0.95      0.96      0.96       657
#    macro avg       0.95      0.96      0.96       657
# weighted avg       0.95      0.96      0.96       657
#
# Performance pick_two_obj_and_place (6):
#               precision    recall  f1-score   support
#
#            6       0.98      0.91      0.95       754
#
#    micro avg       0.98      0.91      0.95       754
#    macro avg       0.98      0.91      0.95       754
# weighted avg       0.98      0.91      0.95       754

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")
plt.title("Matrice de confusion")
plt.xlabel("Pred")
plt.ylabel("True")
plt.show()

# %%
def get_output_and_type_from_data(data):
    output = []
    types = []

    for x in data:
        if x['type'] == 'UNKNOWN': continue
        for desc in x['descriptions']:
            output.append(' '.join(desc['output']))
            types.append(x['type'])

    return output, types

# %%
output_types_df = pd.DataFrame()
output_types_df['output'], output_types_df['types'] = get_output_and_type_from_data(all_data)
output_types_df['y'] = output_types_df['types'].map(types_to_int)
output_types_df.head(10)
# Out:
#                                               output  \
# 0  Move forward towards the stove then turn left ...
# 1  Walk to the stove and then turn left and look ...
# 2  move to the counter across from the fridge pic...
# 3  turn right, walk to the white table on the rig...
# 4  Turn around, move to the square table. Pick up...
# 5  move around to the table pick up the tomato fr...
# 6  Turn to the left and walk forward to the sink ...
# 7  Turn left, go forward, turn right and go to th...
# 8  Turn to your left and go to the dishwasher, tu...
# 9  Move to the counter left of the fridge.  Pick ...
#
#                            types  y
# 0  pick_cool_then_place_in_recep  4
# 1  pick_cool_then_place_in_recep  4
# 2  pick_cool_then_place_in_recep  4
# 3  pick_cool_then_place_in_recep  4
# 4  pick_cool_then_place_in_recep  4
# 5  pick_cool_then_place_in_recep  4
# 6  pick_cool_then_place_in_recep  4
# 7  pick_cool_then_place_in_recep  4
# 8  pick_cool_then_place_in_recep  4
# 9  pick_heat_then_place_in_recep  5

# %%
X_train, X_test, y_train, y_test = train_test_split(output_types_df['output'], output_types_df['y'], 
                                                    test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

clf = LogisticRegression()
clf.fit(X_train_tfidf, y_train)

y_pred = clf.predict(X_test_tfidf)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       476
#            1       0.75      0.66      0.70       709
#            2       0.89      0.93      0.91       701
#            3       0.94      0.94      0.94       623
#            4       0.86      0.93      0.89       614
#            5       0.89      0.94      0.92       657
#            6       0.74      0.71      0.73       754
#
#     accuracy                           0.86      4534
#    macro avg       0.86      0.87      0.87      4534
# weighted avg       0.86      0.86      0.86      4534
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
for type, y in types_to_int.items():
    class_idx = list(output_types_df['y'].unique()).index(y)
    print(f"Performance {type} ({y}):")
    print(classification_report(y_test, y_pred, labels=[y]))
# Out:
# Performance look_at_obj_in_light (0):
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       476
#
#    micro avg       0.98      0.99      0.98       476
#    macro avg       0.98      0.99      0.98       476
# weighted avg       0.98      0.99      0.98       476
#
# Performance pick_and_place_simple (1):
#               precision    recall  f1-score   support
#
#            1       0.75      0.66      0.70       709
#
#    micro avg       0.75      0.66      0.70       709
#    macro avg       0.75      0.66      0.70       709
# weighted avg       0.75      0.66      0.70       709
#
# Performance pick_and_place_with_movable_recep (2):
#               precision    recall  f1-score   support
#
#            2       0.89      0.93      0.91       701
#
#    micro avg       0.89      0.93      0.91       701
#    macro avg       0.89      0.93      0.91       701
# weighted avg       0.89      0.93      0.91       701
#
# Performance pick_clean_then_place_in_recep (3):
#               precision    recall  f1-score   support
#
#            3       0.94      0.94      0.94       623
#
#    micro avg       0.94      0.94      0.94       623
#    macro avg       0.94      0.94      0.94       623
# weighted avg       0.94      0.94      0.94       623
#
# Performance pick_cool_then_place_in_recep (4):
#               precision    recall  f1-score   support
#
#            4       0.86      0.93      0.89       614
#
#    micro avg       0.86      0.93      0.89       614
#    macro avg       0.86      0.93      0.89       614
# weighted avg       0.86      0.93      0.89       614
#
# Performance pick_heat_then_place_in_recep (5):
#               precision    recall  f1-score   support
#
#            5       0.89      0.94      0.92       657
#
#    micro avg       0.89      0.94      0.92       657
#    macro avg       0.89      0.94      0.92       657
# weighted avg       0.89      0.94      0.92       657
#
# Performance pick_two_obj_and_place (6):
#               precision    recall  f1-score   support
#
#            6       0.74      0.71      0.73       754
#
#    micro avg       0.74      0.71      0.73       754
#    macro avg       0.74      0.71      0.73       754
# weighted avg       0.74      0.71      0.73       754

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")
plt.title("Matrice de confusion")
plt.xlabel("Pred")
plt.ylabel("True")
plt.show()

# %% [markdown]
# ## Axe 1 : Instructions - Input et output
#
# Etude du dataset **Alfred** :
#
# - **Input** : instruction de haut niveau d'entrée
# - **Output** : instructions atomiques (élémentaires) données en sortie pour la réalisation de l'instruction d'entrée.
#
# Dans ce premier axe d'étude, nous allons étudier les relations entre les différents triplets d'input et output, selon **Alfred** et selon **ConceptNet**.

# %% [markdown]
# #### Extraction des concepts et relations importantes étant donnée une phrase
#
# **Première approche**
# - **Concepts** : noms
# - **Relations** : verbes

# %%
import nltk
from nltk.corpus import wordnet
import spacy

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

nlp = spacy.load('en_core_web_sm')

def extract_nouns_verbs(sentence):
    doc = nlp(sentence)
    nouns = []
    verbs = []
    for token in doc:
        if token.pos_ == 'NOUN':
            nouns.append(token.lemma_)
        elif token.pos_ == 'VERB':
            verbs.append(token.lemma_)
    nouns = list(set(nouns))
    verbs = list(set(verbs))
    return nouns, verbs
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
for i in np.random.randint(0, len(all_data), 10):
    x = all_data[i]
    sentence = x['descriptions'][0]['input']
    print(sentence)
    nouns, verbs = extract_nouns_verbs(sentence)
    print('\tNouns :\t', nouns)
    print('\tVerbs :\t', verbs)
# Out:
# To heat a piece of apple and place it on the end of the table.
# 	Nouns :	 ['end', 'table', 'apple', 'piece']
# 	Verbs :	 ['place', 'heat']
# Move the bottle from the cabinet to the toilet
# 	Nouns :	 ['toilet', 'cabinet', 'bottle']
# 	Verbs :	 ['move']
# Put the cellphone in the safe.
# 	Nouns :	 ['cellphone']
# 	Verbs :	 ['put']
# Place wet soap on the edge of the bathtub.
# 	Nouns :	 ['edge', 'soap', 'bathtub']
# 	Verbs :	 ['place']
# Slice an apple in the sink and cool a slice of it down in the refrigerator
# 	Nouns :	 ['refrigerator', 'slice', 'sink', 'apple']
# 	Verbs :	 ['cool', 'slice']
# Move a set of keys to a chair.
# 	Nouns :	 ['chair', 'set', 'key']
# 	Verbs :	 ['move']
# Place two pieces of soap on the back end of the toilet.
# 	Nouns :	 ['soap', 'toilet', 'end', 'piece']
# 	Verbs :	 ['place']
# Put two slices of bread on the table.
# 	Nouns :	 ['table', 'bread', 'slice']
# 	Verbs :	 ['put']
# Look at a book by the light of a lamp.
# 	Nouns :	 ['lamp', 'book', 'light']
# 	Verbs :	 ['look']
# Move a credit card to the checkered couch.
# 	Nouns :	 ['card', 'couch', 'credit']
# 	Verbs :	 ['move']

# %% [markdown]
# Les noms dans les descriptions des instructions sont-ils des objets décrits dans la scène ? A quel point ?

# %%
# comptage des noms présents dans les objets de la scène
def compute_correlation_nouns_scene_objects_from_data(data):
    index = 0
    cpt = 0

    for x in data:
        # récupération des noms des objets sur la scène
        objects = set()
        for obj in x['scene']['objects']:
            objects.add(obj['name'].lower())
        for desc in x['descriptions']:
            input = desc['input']
            nouns, _ = extract_nouns_verbs(input)
            for noun in nouns:
                cpt += 1
                if noun.lower() in objects:
                    index += 1

    return index / cpt

# %%
compute_correlation_nouns_scene_objects_from_data(all_data)
# Out:
# 0.2749863106568277

# %%
import re

# classement des objets de la scène qui se retrouvent dans la description des instructions
def get_objets_in_desc_ratio_from_data(data):
    index = {}
    cpt = {}

    for x in data:
        # récupération des noms des objets sur la scène
        objects = set()
        for obj in x['scene']['objects']:
            obj_name = obj['name']
            obj_name = ' '.join(re.findall('[A-Z][a-z]*', obj_name)).lower()
            objects.add(obj_name)
            if obj_name not in index:
                index[obj_name] = 0
                cpt[obj_name] = 0
        # comptage 
        for desc in x['descriptions']:
            input = desc['input']
            for obj_name in objects:
                cpt[obj_name] += 1
                if obj_name in input:
                    index[obj_name] += 1

    ratios = {k: index[k] / cpt[k] for k in index.keys()}     
    return ratios

# %%
objects_ratio = get_objets_in_desc_ratio_from_data(all_data)

# %%
objects_ratio
# Out:
# {'spray bottle': 0.08509263248599741,
#  'dish sponge': 0.0,
#  'glassbottle': 0.0,
#  'spoon': 0.04975124378109453,
#  'fork': 0.03200415831291305,
#  'spatula': 0.021831142793495212,
#  'egg': 0.05190465582535086,
#  'cup': 0.07722581124229598,
#  'plate': 0.06754684270187371,
#  'knife': 0.10195292195737729,
#  'tomato': 0.11130912601173239,
#  'soap bottle': 0.0023094688221709007,
#  'bowl': 0.06579111944965603,
#  'lettuce': 0.06697854013514518,
#  'pepper shaker': 0.0009653226405286998,
#  'mug': 0.06969410280668559,
#  'apple': 0.10796762456374842,
#  'bread': 0.06363703868716121,
#  'kettle': 0.031728834545735954,
#  'cell phone': 0.031509596104268116,
#  'pot': 0.15155565456300588,
#  'wine bottle': 0.01027326895418122,
#  'salt shaker': 0.013514516967401797,
#  'potato': 0.10893294720427713,
#  'butter knife': 0.006501950585175552,
#  'pan': 0.08145837974307567,
#  'pencil': 0.10753821823932525,
#  'paper towel roll': 0.0,
#  'ladle': 0.025976959566297718,
#  'vase': 0.03143143143143143,
#  'statue': 0.03506632108553133,
#  'c d': 0.0,
#  'pen': 0.19286728176011356,
#  'laptop': 0.02747383444338725,
#  'alarm clock': 0.03028834504482675,
#  'book': 0.07810977590126665,
#  'box': 0.14630916914928832,
#  'basket ball': 0.00209351011863224,
#  'pillow': 0.032706945765937204,
#  'key chain': 0.004043767840152236,
#  'credit card': 0.07229529927602733,
#  'newspaper': 0.12093195266272189,
#  'remote control': 0.03427249789739277,
#  'watch': 0.14732673267326732,
#  'watering can': 0.024618414574101428,
#  'baseball bat': 0.021221532091097308,
#  'tennis racket': 0.05387205387205387,
#  'cloth': 0.05833875515072652,
#  'candle': 0.09790044821891955,
#  'soap bar': 0.010381520892810797,
#  'towel': 0.0898001557228134,
#  'hand towel': 0.009862444848170258,
#  'plunger': 0.024656112120425643,
#  'toilet paper': 0.11186088762003633,
#  'scrub brush': 0.0,
#  'tissue box': 0.04054054054054054,
#  'boots': 0.0,
#  'teddy bear': 0.0,
#  'footstool': 0.0}

# %%
sorted_data = sorted(objects_ratio.items(), key=lambda x: x[1])
objects = [i[0] for i in sorted_data]
values = [i[1] for i in sorted_data]
fig, ax = plt.subplots(figsize=(20, 15))
ax.barh(objects, values, alpha=.6)
plt.xlabel("Freq")
plt.ylabel("Objects")
plt.title('Ratio Object in Scene/Object in Instruction')
plt.show()

# %% [markdown]
# Les noms dans les descriptions détaillées des instructions (output) sont-ils des objets décrits dans la scène ? A quel point ?

# %%
# comptage des noms présents dans les objets de la scène
def compute_correlation_nouns_output_scene_objects_from_data(data):
    index = 0
    cpt = 0

    for x in data:
        # récupération des noms des objets sur la scène
        objects = set()
        for obj in x['scene']['objects']:
            objects.add(obj['name'].lower())
        for desc in x['descriptions']:
            output = desc['output']
            for out in output:
                nouns, _ = extract_nouns_verbs(out)
                for noun in nouns:
                    cpt += 1
                    if noun.lower() in objects:
                        index += 1

    return index / cpt

# %%
compute_correlation_nouns_output_scene_objects_from_data(all_data)
# Out:
# 0.18554288886042442

# %%
# classement des objets de la scène qui se retrouvent dans la description détaillée des instructions
def get_objets_in_output_desc_ratio_from_data(data):
    index = {}
    cpt = {}

    for x in data:
        # récupération des noms des objets sur la scène
        objects = set()
        for obj in x['scene']['objects']:
            obj_name = obj['name']
            obj_name = ' '.join(re.findall('[A-Z][a-z]*', obj_name)).lower()
            objects.add(obj_name)
            if obj_name not in index:
                index[obj_name] = 0
                cpt[obj_name] = 0
        # comptage 
        for desc in x['descriptions']:
            output = desc['output']
            for out in output:
                for obj_name in objects:
                    cpt[obj_name] += 1
                    if obj_name in out:
                        index[obj_name] += 1

    ratios = {k: index[k] / cpt[k] for k in index.keys()}     
    return ratios

# %%
objects_output_ratio = get_objets_in_output_desc_ratio_from_data(all_data)

# %%
objects_output_ratio
# Out:
# {'spray bottle': 0.04717734931387876,
#  'dish sponge': 1.839892550275064e-05,
#  'glassbottle': 0.0,
#  'spoon': 0.02433854277070125,
#  'fork': 0.015560865627348583,
#  'spatula': 0.011244291137533,
#  'egg': 0.024772127261865763,
#  'cup': 0.03633438035958607,
#  'plate': 0.0339678984695782,
#  'knife': 0.12272368142138632,
#  'tomato': 0.06238799067311583,
#  'soap bottle': 0.0010404514928902481,
#  'bowl': 0.031406533035114426,
#  'lettuce': 0.0424431040795483,
#  'pepper shaker': 0.00062628870945985,
#  'mug': 0.03296571668135422,
#  'apple': 0.05978648372612876,
#  'bread': 0.04610448422715973,
#  'kettle': 0.014955073236778402,
#  'cell phone': 0.018984119287186324,
#  'pot': 0.07985662806158828,
#  'wine bottle': 0.007277628032345013,
#  'salt shaker': 0.007457653248029599,
#  'potato': 0.058524271096294295,
#  'butter knife': 0.00975682382133995,
#  'pan': 0.03790491973869308,
#  'pencil': 0.0553078143237662,
#  'paper towel roll': 0.00042340165873826306,
#  'ladle': 0.012192613920145723,
#  'vase': 0.017915953102358054,
#  'statue': 0.01961186453713436,
#  'c d': 0.00013389270731054183,
#  'pen': 0.12161194958767699,
#  'laptop': 0.022864623104614377,
#  'alarm clock': 0.01861108631616531,
#  'book': 0.046756909193457416,
#  'box': 0.09415326279738243,
#  'basket ball': 0.0010523546435148646,
#  'pillow': 0.016908476055416167,
#  'key chain': 0.0013308606959746918,
#  'credit card': 0.03623433796139519,
#  'newspaper': 0.06792302057667976,
#  'remote control': 0.015914916408431845,
#  'watch': 0.07053413512557481,
#  'watering can': 0.008097534346283323,
#  'baseball bat': 0.008520306731042317,
#  'tennis racket': 0.02080721985460015,
#  'cloth': 0.033590691207142594,
#  'candle': 0.05320076057677072,
#  'soap bar': 0.006541894116627675,
#  'towel': 0.05614764751754614,
#  'hand towel': 0.003942465990815354,
#  'plunger': 0.010224417294861798,
#  'toilet paper': 0.06017676111255524,
#  'scrub brush': 0.0,
#  'tissue box': 0.027089235127478753,
#  'boots': 0.0025823111684958036,
#  'teddy bear': 0.0017393631255017393,
#  'footstool': 0.0}

# %%
sorted_data = sorted(objects_output_ratio.items(), key=lambda x: x[1])
objects = [i[0] for i in sorted_data]
values = [i[1] for i in sorted_data]
fig, ax = plt.subplots(figsize=(20, 15))
ax.barh(objects, values, alpha=.6)
plt.xlabel("Freq")
plt.ylabel("Objects")
plt.title('Ratio Object in Scene/Object in output Instructions')
plt.show()

# %% [markdown]
# Les noms des objets sont-ils plus présents dans la description de l'instruction (input) ou dans son découpage en instructions élémentaires (output) ?

# %%
objects_ratio_diff = {k: objects_ratio[k] - objects_output_ratio[k] for k in objects_ratio}

# %%
objects_ratio_diff
# Out:
# {'spray bottle': 0.037915283172118654,
#  'dish sponge': -1.839892550275064e-05,
#  'glassbottle': 0.0,
#  'spoon': 0.02541270101039328,
#  'fork': 0.016443292685564465,
#  'spatula': 0.010586851655962211,
#  'egg': 0.027132528563485095,
#  'cup': 0.04089143088270991,
#  'plate': 0.03357894423229551,
#  'knife': -0.020770759464009025,
#  'tomato': 0.048921135338616556,
#  'soap bottle': 0.0012690173292806525,
#  'bowl': 0.034384586414541604,
#  'lettuce': 0.024535436055596875,
#  'pepper shaker': 0.0003390339310688497,
#  'mug': 0.036728386125331365,
#  'apple': 0.04818114083761966,
#  'bread': 0.01753255446000148,
#  'kettle': 0.016773761308957552,
#  'cell phone': 0.012525476817081792,
#  'pot': 0.0716990265014176,
#  'wine bottle': 0.002995640921836207,
#  'salt shaker': 0.006056863719372197,
#  'potato': 0.05040867610798283,
#  'butter knife': -0.003254873236164398,
#  'pan': 0.04355346000438259,
#  'pencil': 0.05223040391555905,
#  'paper towel roll': -0.00042340165873826306,
#  'ladle': 0.013784345646151995,
#  'vase': 0.013515478329073374,
#  'statue': 0.015454456548396969,
#  'c d': -0.00013389270731054183,
#  'pen': 0.07125533217243657,
#  'laptop': 0.004609211338772873,
#  'alarm clock': 0.01167725872866144,
#  'book': 0.031352866707809235,
#  'box': 0.052155906351905895,
#  'basket ball': 0.0010411554751173756,
#  'pillow': 0.015798469710521037,
#  'key chain': 0.0027129071441775445,
#  'credit card': 0.03606096131463214,
#  'newspaper': 0.053008932086042126,
#  'remote control': 0.018357581488960925,
#  'watch': 0.0767925975476925,
#  'watering can': 0.016520880227818106,
#  'baseball bat': 0.012701225360054991,
#  'tennis racket': 0.03306483401745372,
#  'cloth': 0.024748063943583927,
#  'candle': 0.04469968764214883,
#  'soap bar': 0.0038396267761831226,
#  'towel': 0.03365250820526726,
#  'hand towel': 0.0059199788573549034,
#  'plunger': 0.014431694825563845,
#  'toilet paper': 0.051684126507481096,
#  'scrub brush': 0.0,
#  'tissue box': 0.01345130541306179,
#  'boots': -0.0025823111684958036,
#  'teddy bear': -0.0017393631255017393,
#  'footstool': 0.0}

# %%
sorted_data = sorted(objects_ratio_diff.items(), key=lambda x: x[1])
objects = [i[0] for i in sorted_data]
values = [i[1] for i in sorted_data]
fig, ax = plt.subplots(figsize=(20, 15))
ax.barh(objects, values, alpha=.6)
plt.xlabel("Diff")
plt.ylabel("Objects")
plt.title('Ratio Diff In-Out')
plt.show()

# %% [markdown]
# ### Extraction des couples (verbes-objets) étant donnée une phrase

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

### ???? Ne marche pas encore exactement bien
def extract_relations(sentence):
    doc = nlp(sentence)
    relations = []
    for token in doc:
        if token.pos_ == "VERB":
            # noms (objets) liés au verbe
            nouns = [child for child in token.children if child.pos_ == "NOUN"]
            for noun in nouns:
                # autres verbes liés à ce nom
                verbs = [child for child in noun.children if child.pos_ == "VERB" and child != token]
                # création d'un triplet si possible
                if verbs:
                    for verb in verbs:
                        relations.append((token.text, noun.text, verb.text))
                # ajout d'autres triplets
                if len(verbs) > 1:
                    for i in range(len(verbs)):
                        for j in range(i+1, len(verbs)):
                            relations.append((verbs[i].text, noun.text))
                            relations.append((verbs[j].text, noun.text))
    return relations

# %%
for i in np.random.randint(0, len(all_data), 10):
    x = all_data[i]
    sentence = x['descriptions'][0]['input']
    print(sentence)
    relations = extract_relations(sentence)
    print('\t', relations)
# Out:
# Slice the bread, cook a slice put it on the table
# 	 [('cook', 'slice', 'put')]
# place two spray bottles on top of the white cabinet in the bathroom
# 	 []
# Put a cup with a fork in the sink.
# 	 []
# put a sponge in a pan and put the pan on the counter
# 	 []
# place a clean purple cloth on top of the bathroom toilet
# 	 []
# Wash the fork on the table, put it on the white table
# 	 []
# Examine a credit card with the lamp light.
# 	 []
# Place a cup with a pencil in it on a book case shelf
# 	 []
# Inspect a credit card near a lit lamp.
# 	 []
# Slice a tomato, cook a slice
# 	 []
